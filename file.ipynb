# %%
# run in project root to confirm JSON parsing
import json
d = json.load(open("final_rag_corpus.json", "r", encoding="utf-8"))
print("top keys:", list(d.keys()))
print("books:", len(d.get("books", [])))
if d.get("books"):
    print("first book keys:", list(d["books"][0].keys()))
    # check chunks count in first book
    print("first book chunks:", len(d["books"][0].get("chunks", [])))
# Out:
# top keys: ['corpus_metadata', 'books']
# books: 3
# first book keys: ['book_id', 'book_metadata', 'chunks']
# first book chunks: 39
